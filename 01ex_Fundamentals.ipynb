# %% [markdown]
# 0\. Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.

# %%
import function_00_ex

print(f"The square of 5 is: {function_00_ex.square(5)}")
# Out:
# The square of 5 is: 25

# %% [markdown]
# 1\. Write the following as a list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print (ans)

# 2
ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
print (list(ans))
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %%
#Ex solution:

#1
ans = [(i, j) for i in range(3) for j in range(4)] #So to add more than one instruction I only have to list them in this way. 
print(ans)

#2
#map(function to use, numbers to which I apply the function)
#filter(condition, number to which I apply the condition)

ans = [x*x for x in range(5) if x%2 == 0]
print(ans)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %% [markdown]
# 2\. Convert the following function into a pure function with no global variables or side effects

# %%
x = 5
def f(alist):
    for i in range(x):
         alist.append(i)
    return alist

alist = [1,2,3]
ans = f(alist)
print (ans)
print (alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3, 0, 1, 2, 3, 4]

# %%
import copy

def f(alist):
    alist_copy = copy.deepcopy(alist)
    for i in range(5):
        alist_copy.append(i)
    return alist_copy

alist = [1,2,3]
ans = f(alist)
print (ans)
print (alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# 3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
#First version: This does not print the value of the function because the latter is replaced by the decorator (wrapper)
def hello(func):
    def wrapper(*args, **kwargs):
        print("Hello!")
        func(*args, **kwargs) #These two arguments permit to receive in input every kind of variable 
    return wrapper

@hello          #This wraps the function below and prints out everything that is written in the wrapper. Thus I broaden the functions
def square(x):
    return x*x

square(5) #This prints only "Hello!" since the wrapper does not return the value calculated by the funcion

#Second version: Here I add a return in the wrapper function in order to see the actual result of the function
def hello(func):
    def wrapper(*args, **kwargs):
        print("Hello!")
        return func(*args, **kwargs)
    return wrapper

@hello
def square(x):
    return x*x

print(square(5)) 
#If I write only square(5) I will see only the decorator even in this case
# Out:
# Hello!
# Hello!
# 25

# %% [markdown]
# 4\. Write the factorial function so that it a) does and b) does not use recursion.

# %%
#Non recursive factorial function

def factorial(N):
    result = 1
    for i in range(N):
        result *= (i+1)
    return result

print(factorial(4))
# Out:
# 24

# %%
def recursive_fac(N):
    if(N > 1):
        return N * recursive_fac(N - 1)
    else: return 1 #I neet to return a number at a point, otherwise the function will not work

print(recursive_fac(5))
# Out:
# 120

# %% [markdown]
# 5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
# radii = [1,2,3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.

# %%
from math import pi

densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
radii = [1,2,3]

weightlist = [
    lambda r: 2*pi*r,
    lambda r: pi*r**2,
    lambda r: (4/3)*pi*r**3
]

for element in densities:
        for i in range(3):    
            W =list(weightlist[i](r)*d for d, r in zip(densities[element], radii))
            if(i==0):
                 print(f"linear weights for {element} are {W}")
            elif(i==1):
                 print(f"Superficial weights for {element} are {W}")
            else:
                 print(f"Volume weights for {element} are {W}\n")
# Out:
# linear weights for Al are [3.141592653589793, 12.566370614359172, 37.69911184307752]
# Superficial weights for Al are [1.5707963267948966, 12.566370614359172, 56.548667764616276]
# Volume weights for Al are [2.0943951023931953, 33.510321638291124, 226.19467105846508]
#
# linear weights for Fe are [18.84955592153876, 50.26548245743669, 94.24777960769379]
# Superficial weights for Fe are [9.42477796076938, 50.26548245743669, 141.3716694115407]
# Volume weights for Fe are [12.566370614359172, 134.0412865531645, 565.4866776461627]
#
# linear weights for Pb are [94.24777960769379, 251.32741228718345, 565.4866776461628]
# Superficial weights for Pb are [47.12388980384689, 251.32741228718345, 848.2300164692441]
# Volume weights for Pb are [62.831853071795855, 670.2064327658225, 3392.920065876976]

# %% [markdown]
# 6\. Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
# class Dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```

# %%
#Finish this
